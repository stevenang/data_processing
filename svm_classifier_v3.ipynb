# %% [markdown]
# ### SVM Classsifier

# %%
import chardet
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import scipy
import seaborn as sns
import sys
import warnings

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report, roc_curve
from scipy import stats

# %% [markdown]
# #### Load Data

# %%
data = pd.read_csv('processed_data/combined.csv')
data.head()
# Out:
#     subject_id  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0  sub-0023001                  5309.7              434.0
# 1  sub-0010011                  4813.7              785.8
# 2  sub-2427434                  4891.9              423.1
# 3  sub-2230510                  2535.1              543.5
# 4  sub-0023006                  4477.6              378.9
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus  \
# 0                       12642.4                 65841.3         8371.4
# 1                        9892.7                 45860.8         6487.5
# 2                       11186.9                 55092.0         7097.7
# 3                       12772.8                 56887.6         6487.1
# 4                       11991.9                 62007.1         6189.8
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# 0        4888.4        6444.8         1853.9          683.8  ...
# 1        3429.7        5657.9         1606.1          705.3  ...
# 2        4590.8        6129.0         1644.6          509.2  ...
# 3        3495.2        5464.6         1604.3          529.8  ...
# 4        3987.9        5120.0         1498.6          537.6  ...
#
#    rh_superiortemporal_volume  rh_supramarginal_volume  rh_frontalpole_volume  \
# 0                     14174.0                   1498.0                 3142.0
# 1                     11197.0                   1626.0                 2100.0
# 2                     15959.0                   1767.0                 2944.0
# 3                      5974.0                   1634.0                 1771.0
# 4                     10689.0                   1231.0                 2496.0
#
#    rh_temporalpole_volume  rh_transversetemporal_volume  rh_insula_volume  \
# 0                  1226.0                        8238.0         1270732.0
# 1                   875.0                        5565.0          992979.0
# 2                  1245.0                        7786.0         1089479.0
# 3                   968.0                        5007.0          970763.0
# 4                  1124.0                        7411.0         1045207.0
#
#    gender   age  diagnosis  adhd_binary
# 0     0.0  9.33    Control          NaN
# 1     1.0  9.16       ADHD          NaN
# 2     1.0  8.08    Control          NaN
# 3     0.0  9.17       ADHD          NaN
# 4     1.0  9.25    Control          NaN
#
# [5 rows x 285 columns]

# %%
# Update adhd_binary column based on diagnosis
data['adhd_binary'] = data['diagnosis'].apply(lambda x: 1 if x == 'ADHD' else 0)
data.head()
# Out:
#     subject_id  Left-Lateral-Ventricle  Left-Inf-Lat-Vent  \
# 0  sub-0023001                  5309.7              434.0
# 1  sub-0010011                  4813.7              785.8
# 2  sub-2427434                  4891.9              423.1
# 3  sub-2230510                  2535.1              543.5
# 4  sub-0023006                  4477.6              378.9
#
#    Left-Cerebellum-White-Matter  Left-Cerebellum-Cortex  Left-Thalamus  \
# 0                       12642.4                 65841.3         8371.4
# 1                        9892.7                 45860.8         6487.5
# 2                       11186.9                 55092.0         7097.7
# 3                       12772.8                 56887.6         6487.1
# 4                       11991.9                 62007.1         6189.8
#
#    Left-Caudate  Left-Putamen  Left-Pallidum  3rd-Ventricle  ...  \
# 0        4888.4        6444.8         1853.9          683.8  ...
# 1        3429.7        5657.9         1606.1          705.3  ...
# 2        4590.8        6129.0         1644.6          509.2  ...
# 3        3495.2        5464.6         1604.3          529.8  ...
# 4        3987.9        5120.0         1498.6          537.6  ...
#
#    rh_superiortemporal_volume  rh_supramarginal_volume  rh_frontalpole_volume  \
# 0                     14174.0                   1498.0                 3142.0
# 1                     11197.0                   1626.0                 2100.0
# 2                     15959.0                   1767.0                 2944.0
# 3                      5974.0                   1634.0                 1771.0
# 4                     10689.0                   1231.0                 2496.0
#
#    rh_temporalpole_volume  rh_transversetemporal_volume  rh_insula_volume  \
# 0                  1226.0                        8238.0         1270732.0
# 1                   875.0                        5565.0          992979.0
# 2                  1245.0                        7786.0         1089479.0
# 3                   968.0                        5007.0          970763.0
# 4                  1124.0                        7411.0         1045207.0
#
#    gender   age  diagnosis  adhd_binary
# 0     0.0  9.33    Control            0
# 1     1.0  9.16       ADHD            1
# 2     1.0  8.08    Control            0
# 3     0.0  9.17       ADHD            1
# 4     1.0  9.25    Control            0
#
# [5 rows x 285 columns]

# %%
# First, let's check which columns have NaN values
print("NaN count in each column:")
nan_counts = data.isna().sum()
print(nan_counts)
# Out:
# NaN count in each column:
# subject_id                      0
# Left-Lateral-Ventricle          0
# Left-Inf-Lat-Vent               0
# Left-Cerebellum-White-Matter    0
# Left-Cerebellum-Cortex          0
#                                ..
# rh_insula_volume                0
# gender                          0
# age                             0
# diagnosis                       0
# adhd_binary                     0
# Length: 285, dtype: int64

# %%
# Identify columns with NaN values
columns_with_nans = nan_counts[nan_counts > 0].index.tolist()
print(f"\nColumns containing NaN values: {columns_with_nans}")
# Out:
# Columns containing NaN values: ['eTIV']

# %%
fields_to_drop = ['subject_id', 'gender', 'age', 'diagnosis'] + columns_with_nans
clean_data = data.drop(columns = fields_to_drop)
features = ['lh_precuneus_thickness', 'rh_middletemporal_thickness', 'rh_frontalpole_thickness', 'lh_transversetemporal_thickness', 'lhSurfaceHoles', 'lh_middletemporal_thickness', 'rh_lateralorbitofrontal_area', 'lh_bankssts_volume', 'Right-Thalamus', 'rh_precuneus_thickness', 'lh_precuneus_area', 'rh_precuneus_volume', 'rh_cuneus_volume', 'rh_paracentral_volume', 'Left-Accumbens-area', 'lh_cuneus_thickness', 'lh_lateralorbitofrontal_volume', 'rh_fusiform_volume', 'lh_postcentral_thickness', 'SurfaceHoles']
X = clean_data[features]
y = clean_data['adhd_binary']

# %%
X.head()
# Out:
#    lh_precuneus_thickness  rh_middletemporal_thickness  \
# 0                   2.783                        2.861
# 1                   2.566                        2.233
# 2                   3.135                        2.950
# 3                   1.750                        2.272
# 4                   3.092                        2.757
#
#    rh_frontalpole_thickness  lh_transversetemporal_thickness  lhSurfaceHoles  \
# 0                     3.895                            3.098             7.0
# 1                     3.379                            2.755            45.0
# 2                     3.914                            3.156            12.0
# 3                     3.139                            2.482            48.0
# 4                     3.592                            3.097            23.0
#
#    lh_middletemporal_thickness  rh_lateralorbitofrontal_area  \
# 0                        2.805                        3723.0
# 1                        2.158                        1990.0
# 2                        2.671                        3087.0
# 3                        2.092                        2664.0
# 4                        2.910                        3052.0
#
#    lh_bankssts_volume  Right-Thalamus  rh_precuneus_thickness  \
# 0              1920.0          8029.6                   2.772
# 1              2442.0          6906.1                   2.662
# 2              2279.0          7091.7                   3.149
# 3              1336.0          6579.0                   2.243
# 4              1580.0          5872.5                   3.030
#
#    lh_precuneus_area  rh_precuneus_volume  rh_cuneus_volume  \
# 0              994.0               2912.0            1708.0
# 1              768.0               1347.0            1502.0
# 2              802.0               2387.0            1816.0
# 3              781.0               1296.0            1472.0
# 4              587.0               1173.0            1596.0
#
#    rh_paracentral_volume  Left-Accumbens-area  lh_cuneus_thickness  \
# 0                 4618.0                731.1                2.570
# 1                 4432.0                669.5                2.437
# 2                 5041.0                704.9                3.158
# 3                 4857.0                587.8                2.605
# 4                 4117.0                521.8                2.994
#
#    lh_lateralorbitofrontal_volume  rh_fusiform_volume  \
# 0                          7829.0             16662.0
# 1                          5674.0             15507.0
# 2                          7444.0             13919.0
# 3                          5934.0             14450.0
# 4                          7598.0             16832.0
#
#    lh_postcentral_thickness  SurfaceHoles
# 0                     2.594          20.0
# 1                     2.241          84.0
# 2                     2.748          26.0
# 3                     2.248          88.0
# 4                     2.641          38.0

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: adhd_binary, dtype: int64

# %%
# Print out original dataset size
print(f"\nTotal number of samples: {len(clean_data)}")
print(f"Number of ADHD samples (class 1): {sum(y == 1)}")
print(f"Number of control samples (class 0): {sum(y == 0)}")
# Out:
# Total number of samples: 434
# Number of ADHD samples (class 1): 187
# Number of control samples (class 0): 247

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
# Print training and testing set sizes
print(f"\nTraining set size: {len(X_train)} samples")
print(f"Testing set size: {len(X_test)} samples")
print(f"Training set class distribution: ADHD: {sum(y_train == 1)}, Control: {sum(y_train == 0)}")
print(f"Testing set class distribution: ADHD: {sum(y_test == 1)}, Control: {sum(y_test == 0)}")
# Out:
# Training set size: 303 samples
# Testing set size: 131 samples
# Training set class distribution: ADHD: 131, Control: 172
# Testing set class distribution: ADHD: 56, Control: 75

# %%
X_train.head()
# Out:
#      lh_precuneus_thickness  rh_middletemporal_thickness  \
# 84                    2.958                        2.599
# 54                    2.505                        2.263
# 299                   2.323                        2.355
# 316                   2.153                        2.273
# 56                    3.018                        2.673
#
#      rh_frontalpole_thickness  lh_transversetemporal_thickness  \
# 84                      3.159                            3.116
# 54                      3.681                            2.632
# 299                     3.119                            2.855
# 316                     3.253                            2.638
# 56                      3.012                            3.028
#
#      lhSurfaceHoles  lh_middletemporal_thickness  \
# 84             19.0                        2.459
# 54             63.0                        2.130
# 299            43.0                        2.362
# 316            43.0                        2.393
# 56             17.0                        2.691
#
#      rh_lateralorbitofrontal_area  lh_bankssts_volume  Right-Thalamus  \
# 84                         3382.0              1906.0          8588.8
# 54                         3147.0              2384.0          6801.3
# 299                        3866.0              1829.0          7211.0
# 316                        3771.0              1719.0          6635.8
# 56                         3055.0              2367.0          8709.4
#
#      rh_precuneus_thickness  lh_precuneus_area  rh_precuneus_volume  \
# 84                    2.859              850.0               2832.0
# 54                    2.468             1056.0               2245.0
# 299                   2.434             1186.0               1811.0
# 316                   2.562             1031.0               1478.0
# 56                    2.827              873.0               2416.0
#
#      rh_cuneus_volume  rh_paracentral_volume  Left-Accumbens-area  \
# 84             1847.0                 3853.0                693.7
# 54             1440.0                 4646.0                768.3
# 299            1783.0                 3910.0                773.5
# 316            1216.0                 3725.0                523.4
# 56             2471.0                 4970.0                786.3
#
#      lh_cuneus_thickness  lh_lateralorbitofrontal_volume  rh_fusiform_volume  \
# 84                 3.037                          7552.0             21455.0
# 54                 2.955                          6986.0             19008.0
# 299                3.187                          8717.0             16346.0
# 316                2.905                          6282.0             20537.0
# 56                 3.160                          7702.0             17979.0
#
#      lh_postcentral_thickness  SurfaceHoles
# 84                      2.761          43.0
# 54                      2.327         113.0
# 299                     2.412          88.0
# 316                     2.070          94.0
# 56                      2.654          38.0

# %%
X_test.head()
# Out:
#      lh_precuneus_thickness  rh_middletemporal_thickness  \
# 183                   2.506                        2.306
# 97                    2.681                        2.481
# 387                   2.640                        2.741
# 43                    2.881                        2.455
# 343                   2.732                        2.810
#
#      rh_frontalpole_thickness  lh_transversetemporal_thickness  \
# 183                     3.367                            2.606
# 97                      3.476                            3.029
# 387                     3.834                            2.836
# 43                      3.625                            2.939
# 343                     3.407                            2.793
#
#      lhSurfaceHoles  lh_middletemporal_thickness  \
# 183            39.0                        2.298
# 97              9.0                        2.602
# 387            11.0                        2.647
# 43             15.0                        2.549
# 343            23.0                        2.494
#
#      rh_lateralorbitofrontal_area  lh_bankssts_volume  Right-Thalamus  \
# 183                        3760.0              3008.0          6795.3
# 97                         4035.0              2764.0          8257.4
# 387                        2999.0              3016.0          7499.3
# 43                         3315.0              1425.0          7985.1
# 343                        3705.0              2124.0          8003.3
#
#      rh_precuneus_thickness  lh_precuneus_area  rh_precuneus_volume  \
# 183                   2.413             1150.0               2943.0
# 97                    2.855             1110.0               2623.0
# 387                   2.605              898.0               1592.0
# 43                    2.998              868.0               2874.0
# 343                   2.824             1056.0               2806.0
#
#      rh_cuneus_volume  rh_paracentral_volume  Left-Accumbens-area  \
# 183            1367.0                 5797.0                845.6
# 97             1706.0                 3796.0                825.3
# 387            2137.0                 4923.0                668.4
# 43             1348.0                 4709.0                748.7
# 343            2123.0                 5952.0                665.2
#
#      lh_cuneus_thickness  lh_lateralorbitofrontal_volume  rh_fusiform_volume  \
# 183                3.173                          7357.0             18211.0
# 97                 2.650                          8092.0             19322.0
# 387                2.737                          6308.0             17507.0
# 43                 2.749                          7595.0             17660.0
# 343                2.698                          7426.0             14273.0
#
#      lh_postcentral_thickness  SurfaceHoles
# 183                     2.520          73.0
# 97                      2.403          26.0
# 387                     2.419          23.0
# 43                      2.545          33.0
# 343                     2.620          36.0

# %%
# Standardize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create SVM classifier
svm = SVC(kernel='rbf', probability=True, random_state=42)

# %%
# Cross-validation
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(svm, X_train_scaled, y_train, cv=cv, scoring='accuracy')

print(f"Cross-validation accuracy scores: {cv_scores}")
print(f"Mean CV accuracy: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
# Out:
# Cross-validation accuracy scores: [0.70491803 0.63934426 0.63934426 0.73333333 0.71666667]
# Mean CV accuracy: 0.6867 ± 0.0397

# %%
# Train the model on the full training set
svm.fit(X_train_scaled, y_train)
# Out:
# SVC(probability=True, random_state=42)

# %%
# Make predictions on test set
y_pred = svm.predict(X_test_scaled)
y_pred_prob = svm.predict_proba(X_test_scaled)[:, 1]  # Probability estimates for ROC curve

# %%
# Calculate performance metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred_prob)

# Print performance metrics
print("\nPerformance Metrics:")
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"AUC: {auc:.4f}")
# Out:
# Performance Metrics:
# Accuracy: 0.7328
# Precision: 0.7059
# Recall: 0.6429
# F1 Score: 0.6729
# AUC: 0.7961

# %%
# Confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("\nConfusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[60 15]
#  [20 36]]

# %%
# Detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.80      0.77        75
#            1       0.71      0.64      0.67        56
#
#     accuracy                           0.73       131
#    macro avg       0.73      0.72      0.72       131
# weighted avg       0.73      0.73      0.73       131

# %%
# Plot ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'AUC = {auc:.4f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
